# %%
def logistic(r,f) :
    for i in range(10) :
        f = f*r*f*(1-f)
        print(f)
    return
print("r:4.5,f:0.5 일때")
logistic(4.5,0.5)
print("r:4.5,f:0.51 일때")
logistic(4.5,0.51)
print("r:4.5,f:0.501 일때")
logistic(4.5,0.501)
# Out:
# r:4.5,f:0.5 일때
# 0.5625
# 0.6229248046875
# 0.6584332102729604
# 0.6663641241976102
# 0.6666662548975268
# 0.6666666666659037
# 0.6666666666666667
# 0.6666666666666666
# 0.6666666666666667
# 0.6666666666666666

# %%
def fibonacci (n) :
    a = 0
    f = [1,1]
    while a < n :
        a += 1
        fn = f[-1]+ f[-2]
        f.append(fn)
    f = f[:n]
    return f

fibonacci(5)
# Out:
# [1, 1, 2, 3, 5]
